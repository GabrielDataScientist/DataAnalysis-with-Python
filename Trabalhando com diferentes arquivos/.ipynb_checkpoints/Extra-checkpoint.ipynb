# %%
import pandas as pd

# %%
df = pd.read_csv("nome_alunos.csv", sep=";")

# %%
df
# Out:
#           nome  ID_aluno                 dominio  \
# 0         JOSE       189  @dominiodoemail.com.br
# 1         JOAO        58     @servicodoemail.com
# 2      ANTONIO       204     @servicodoemail.com
# 3    FRANCISCO       383  @dominiodoemail.com.br
# 4       CARLOS       231     @servicodoemail.com
# ..         ...       ...                     ...
# 395     ROSANE         9  @dominiodoemail.com.br
# 396    IVONETE       378     @servicodoemail.com
# 397    LUCIANE        50  @dominiodoemail.com.br
# 398    ISADORA       244  @dominiodoemail.com.br
# 399      NILZA       387     @servicodoemail.com
#
#                                email
# 0         jose@dominiodoemail.com.br
# 1            joao@servicodoemail.com
# 2         antonio@servicodoemail.com
# 3    francisco@dominiodoemail.com.br
# 4          carlos@servicodoemail.com
# ..                               ...
# 395     rosane@dominiodoemail.com.br
# 396       ivonete@servicodoemail.com
# ...

# %% [markdown]
# # Iterando sobre o dataframe

# %%
for i in df:
    print(i)
# Out:
# nome
# ID_aluno
# dominio
# email

# %%
#Retorna todos os dados da linha
for i, row in df.iterrows():
    print(f"Linha: {i}")
    print("")
    print(row)
    print("")
# Out:
# Linha: 0
#
# nome                              JOSE
# ID_aluno                           189
# dominio         @dominiodoemail.com.br
# email       jose@dominiodoemail.com.br
# Name: 0, dtype: object
#
# Linha: 1
#
# nome                           JOAO
# ID_aluno                         58
# dominio         @servicodoemail.com
# email       joao@servicodoemail.com
# Name: 1, dtype: object
#
# Linha: 2
#
# nome                           ANTONIO
# ID_aluno                           204
# dominio            @servicodoemail.com
# email       antonio@servicodoemail.com
# Name: 2, dtype: object
#
# Linha: 3
#
# nome                              FRANCISCO
# ID_aluno                                383
# dominio              @dominiodoemail.com.br
# email       francisco@dominiodoemail.com.br
# Name: 3, dtype: object
#
# Linha: 4
#
# nome                           CARLOS
# ID_aluno                          231
# dominio           @servicodoemail.com
# email       carlos@servicodoemail.com
# ...

# %%
#Retorna todos os dados de uma coluna específica
for i in df['nome']:
    print(i)
# Out:
# JOSE
# JOAO
# ANTONIO
# FRANCISCO
# CARLOS
# PAULO
# PEDRO
# LUCAS
# LUIZ
# MARCOS
# LUIS
# GABRIEL
# RAFAEL
# DANIEL
# MARCELO
# BRUNO
# EDUARDO
# FELIPE
# RAIMUNDO
# RODRIGO
# MANOEL
# MATEUS
# ANDRE
# FERNANDO
# FABIO
# LEONARDO
# GUSTAVO
# GUILHERME
# LEANDRO
# TIAGO
# ANDERSON
# RICARDO
# MARCIO
# JORGE
# SEBASTIAO
# ALEXANDRE
# ROBERTO
# EDSON
# DIEGO
# VITOR
# SERGIO
# CLAUDIO
# MATHEUS
# THIAGO
# GERALDO
# ADRIANO
# LUCIANO
# JULIO
# RENATO
# ALEX
# VINICIUS
# ROGERIO
# SAMUEL
# RONALDO
# MARIO
# FLAVIO
# DOUGLAS
# IGOR
# DAVI
# MANUEL
# JEFERSON
# CICERO
# VICTOR
# MIGUEL
# ROBSON
# MAURICIO
# DANILO
# HENRIQUE
# CAIO
# REGINALDO
# JOAQUIM
# BENEDITO
# GILBERTO
# MARCO
# ALAN
# NELSON
# CRISTIANO
# ELIAS
# WILSON
# VALDIR
# EMERSON
# LUAN
# DAVID
# RENAN
# SEVERINO
# FABRICIO
# MAURO
# JONAS
# GILMAR
# JEAN
# FABIANO
# WESLEY
# DIOGO
# ADILSON
# JAIR
# ALESSANDRO
# EVERTON
# OSVALDO
# GILSON
# WILLIAN
# JOEL
# SILVIO
# HELIO
# MAICON
# REINALDO
# PABLO
# ARTUR
# VAGNER
# ...

# %%
#Retornando dados de mais de uma coluna especificada
for linha, idaluno in df[['nome', 'ID_aluno']].iterrows():
    print(idaluno)
# Out:
# nome        JOSE
# ID_aluno     189
# Name: 0, dtype: object
# nome        JOAO
# ID_aluno      58
# Name: 1, dtype: object
# nome        ANTONIO
# ID_aluno        204
# Name: 2, dtype: object
# nome        FRANCISCO
# ID_aluno          383
# Name: 3, dtype: object
# nome        CARLOS
# ID_aluno       231
# Name: 4, dtype: object
# nome        PAULO
# ID_aluno      285
# Name: 5, dtype: object
# nome        PEDRO
# ID_aluno      105
# Name: 6, dtype: object
# nome        LUCAS
# ID_aluno      237
# Name: 7, dtype: object
# nome        LUIZ
# ID_aluno       5
# Name: 8, dtype: object
# nome        MARCOS
# ID_aluno       268
# Name: 9, dtype: object
# nome        LUIS
# ID_aluno      59
# Name: 10, dtype: object
# nome        GABRIEL
# ID_aluno        132
# Name: 11, dtype: object
# nome        RAFAEL
# ID_aluno        13
# Name: 12, dtype: object
# nome        DANIEL
# ID_aluno       172
# Name: 13, dtype: object
# nome        MARCELO
# ID_aluno        322
# Name: 14, dtype: object
# ...

# %%
#Retornando dados de mais de uma coluna especificada
for i, id_aluno in df[['nome', 'ID_aluno']].iterrows():
    print(f"Nome: {id_aluno['nome']} -> Id_aluno: {id_aluno['ID_aluno']}")
# Out:
# Nome: JOSE -> Id_aluno: 189
# Nome: JOAO -> Id_aluno: 58
# Nome: ANTONIO -> Id_aluno: 204
# Nome: FRANCISCO -> Id_aluno: 383
# Nome: CARLOS -> Id_aluno: 231
# Nome: PAULO -> Id_aluno: 285
# Nome: PEDRO -> Id_aluno: 105
# Nome: LUCAS -> Id_aluno: 237
# Nome: LUIZ -> Id_aluno: 5
# Nome: MARCOS -> Id_aluno: 268
# Nome: LUIS -> Id_aluno: 59
# Nome: GABRIEL -> Id_aluno: 132
# Nome: RAFAEL -> Id_aluno: 13
# Nome: DANIEL -> Id_aluno: 172
# Nome: MARCELO -> Id_aluno: 322
# Nome: BRUNO -> Id_aluno: 90
# Nome: EDUARDO -> Id_aluno: 250
# Nome: FELIPE -> Id_aluno: 171
# Nome: RAIMUNDO -> Id_aluno: 169
# Nome: RODRIGO -> Id_aluno: 150
# Nome: MANOEL -> Id_aluno: 225
# Nome: MATEUS -> Id_aluno: 92
# Nome: ANDRE -> Id_aluno: 212
# Nome: FERNANDO -> Id_aluno: 219
# Nome: FABIO -> Id_aluno: 109
# Nome: LEONARDO -> Id_aluno: 381
# Nome: GUSTAVO -> Id_aluno: 173
# Nome: GUILHERME -> Id_aluno: 186
# Nome: LEANDRO -> Id_aluno: 139
# Nome: TIAGO -> Id_aluno: 315
# Nome: ANDERSON -> Id_aluno: 264
# ...
